# %% [markdown]
# <a href="https://colab.research.google.com/github/SharWarr/ML_Projects/blob/main/PySparkTransformations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 54 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 69.7 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=c646ef194da89a071836253087747197c0eddff8e85cdc4c92099e1958fc4ac9
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
from pyspark.sql import SparkSession
from pyspark import SparkConf
from pyspark.context import SparkContext
sc = SparkContext.getOrCreate(SparkConf())
lines=sc.textFile("NOTICE")

# %%
lines.getNumPartitions()
# Out:
# 2

# %%
words = lines.flatMap(lambda x:x.split(" "))

# %%
lines.count()
# Out:
# 1174

# %%
words.count()
# Out:
# 6152

# %%
wordpair = words.map(lambda x: (x,1))

# %%
wordcount = wordpair.reduceByKey(lambda x, y: x+y)

# %%
wordcount.collect()
# Out:
# [('Apache', 147),
#  ('Spark', 1),
#  ('2014', 5),
#  ('The', 129),
#  ('', 1257),
#  ('developed', 35),
#  ('at', 21),
#  ('Export', 3),
#  ('distribution', 15),
#  ('software.', 3),
#  ('country', 1),
#  ('in', 35),
#  ('reside', 3),
#  ('may', 9),
#  ('have', 6),
#  ('restrictions', 1),
#  ('possession,', 2),
#  ('use,', 5),
#  ('and/or', 3),
#  ('country,', 1),
#  ('of', 106),
#  ('using', 3),
#  ('software,', 4),
#  ('check', 1),
#  ("country's", 1),
#  ('laws,', 1),
#  ('policies', 1),
#  ('this', 28),
#  ('is', 42),
#  ('<http://www.wassenaar.org/>', 1),
#  ('more', 7),
#  ('information.', 1),
#  ('Industry', 1),
#  ('Security', 1),
#  ('(BIS),', 1),
#  ('as', 19),
#  ('Commodity', 1),
#  ('Number', 1),
#  ('security', 1),
#  ('functions', 1),
#  ('algorithms.', 1),
#  ('form', 4),
#  ('eligible', 1),
#  ('export', 1),
#  ('ENC', 1),
#  ('exception', 1),
#  ('BIS', 1),
#  ('Administration', 1),
#  ('both', 3),
#  ('source', 15),
#  ('code.', 1),
#  ('following', 25),
#  ('provides', 2),
#  ('details', 3),
#  ('software:', 1),
#  ('uses', 3),
#  ('(https://commons.apache.org/proper/commons-crypto/)', 1),
#  ('support', 2),
#  ('authentication,', 1),
#  ('decryption', 1),
#  ('sent', 1),
#  ('network', 1),
#  ('//', 4),
#  ('NOTICE', 6),
#  ('4d', 2),
#  ('Hive', 5),
#  ('2016', 6),
#  ('only', 1),
#  ('specific', 3),
#  ('components,', 1),
#  ('notes', 1),
#  ('are', 20),
#  ('files', 6),
#  ('created', 7),
#  ('Saloranta.', 2),
#  ('additional', 2),
#  ('credits', 1),
#  ('reported', 1),
#  ('CREDITS', 2),
#  ('file.', 4),
#  ('Objenesis', 1),
#  ('Leonardo', 1),
#  ('XBean', 1),
#  ('ASM', 1),
#  ('--------------------------------------', 1),
#  ('OW2', 3),
#  ('(http://asm.ow2.org/)', 1),
#  ('binary', 10),
#  ('org.iq80.leveldb:leveldb-api', 1),
#  ('(https://github.com/dain/leveldb),', 1),
#  ('*', 139),
#  ('2011', 3),
#  ('Dain', 1),
#  ('Sundstrom', 1),
#  ('FuseSource', 2),
#  ('Corp.', 3),
#  ('(https://github.com/fusesource/hawtjni),', 1),
#  ('Progress', 1),
#  ('Corporation', 6),
#  ('subsidiaries', 1),
#  ('IBM', 4),
#  ('others.', 1),
#  ('2.2.4,', 1),
#  ('Project', 4),
#  ('=================', 1),
#  ('Please', 1),
#  ('visit', 1),
#  ('site', 1),
#  ('information:', 1),
#  ('version', 7),
#  ('2.0', 9),
#  ('(the', 1),
#  ('"License");', 1),
#  ('use', 5),
#  ('compliance', 1),
#  ('License.', 4),
#  ('obtain', 1),
#  ('at:', 30),
#  ('law', 1),
#  ('an', 14),
#  ('"AS', 1),
#  ('IS"', 1),
#  ('BASIS,', 1),
#  ('CONDITIONS', 1),
#  ('OF', 1),
#  ('KIND,', 1),
#  ('language', 1),
#  ('limitations', 1),
#  ('refer', 1),
#  ('LICENSE.<component>.txt', 1),
#  ("'license'", 1),
#  ('directory', 1),
#  ('components', 3),
#  ('depends', 18),
#  ('-------------------------------------------------------------------------------',
#   1),
#  ('extensions', 2),
#  ('Java', 19),
#  ('Collections', 2),
#  ('derived', 4),
#  ('JSR-166', 1),
#  ('Lea,', 1),
#  ('Jason', 2),
#  ('Greene:', 1),
#  ('LICENSE:', 28),
#  ('license/LICENSE.jsr166y.txt', 1),
#  ('(Public', 4),
#  ('Domain)', 4),
#  ('HOMEPAGE:', 27),
#  ('http://viewvc.jboss.org/cgi-bin/viewvc.cgi/jbosscache/experimental/jsr166/',
#   1),
#  ('modified', 17),
#  ('Public', 4),
#  ('Domain', 1),
#  ('Encoder', 1),
#  ('Decoder,', 1),
#  ('obtained', 31),
#  ('http://iharder.sourceforge.net/current/java/base64/', 1),
#  ("'Webbit',", 2),
#  ('event', 3),
#  ('based', 7),
#  ('HTTP', 2),
#  ('server,', 1),
#  ('(BSD', 3),
#  ('License)', 12),
#  ("'SLF4J',", 2),
#  ('simple', 4),
#  ('logging', 6),
#  ('facade', 2),
#  ('Java,', 4),
#  ('license/LICENSE.slf4j.txt', 1),
#  ('(MIT', 5),
#  ('http://www.slf4j.org/', 1),
#  ("'ArrayDeque',", 1),
#  ('Josh', 1),
#  ('Google,', 3),
#  ('Inc:', 1),
#  ('license/LICENSE.deque.txt', 1),
#  ('open', 3),
#  ('license/LICENSE.harmony.txt', 1),
#  ('Roland', 3),
#  ("Kuhn's", 1),
#  ('Dmitriy', 1),
#  ('non-intrusive', 1),
#  ('MPSC', 1),
#  ('It', 11),
#  ('license/LICENSE.abstractnodequeue.txt', 1),
#  ('decompression', 4),
#  ('library', 10),
#  ('Matthew', 1),
#  ('license/LICENSE.jbzip2.txt', 1),
#  ('C', 1),
#  ('construct', 1),
#  ('array', 1),
#  ('transformed', 1),
#  ('input', 1),
#  ('constant-size', 1),
#  ('alphabet', 1),
#  ('Yuta', 1),
#  ('Nitsan', 1),
#  ("'JCTools',", 1),
#  ('JVM,', 1),
#  ('license/LICENSE.jctools.txt', 1),
#  ('re-implementation', 2),
#  ('zlib', 2),
#  ('license/LICENSE.jzlib.txt', 2),
#  ('style', 2),
#  ('encoding', 1),
#  ('LZF', 4),
#  ('format,', 4),
#  ('https://github.com/ning/compress', 1),
#  ('LZ4', 1),
#  ('Adrien', 1),
#  ('LZMA', 1),
#  ('library,', 2),
#  ('Kinney.', 1),
#  ('license/LICENSE.jfastlz.txt', 1),
#  ("Buffers',", 2),
#  ("Google's", 3),
#  ('interchange', 2),
#  ('license/LICENSE.protobuf.txt', 1),
#  ('(New', 3),
#  ('http://code.google.com/p/protobuf/', 1),
#  ("'Bouncy", 1),
#  ('Castle', 1),
#  ("APIs'", 1),
#  ('generate', 1),
#  ('self-signed', 1),
#  ('when', 2),
#  ('JVM', 1),
#  ('provide', 1),
#  ('license/LICENSE.bouncycastle.txt', 1),
#  ("'Snappy',", 1),
#  ('produced', 5),
#  ('Google', 5),
#  ('license/LICENSE.snappy.txt', 1),
#  ("'JBoss", 2),
#  ('alternative', 1),
#  ('serialization', 1),
#  ('license/LICENSE.jboss-marshalling.txt', 1),
#  ('(GNU', 2),
#  ('2.1)', 2),
#  ("'Caliper',", 1),
#  ('micro-', 1),
#  ('benchmarking', 1),
#  ('license/LICENSE.caliper.txt', 1),
#  ("Logging',", 2),
#  ("Log4J',", 2),
#  ('license/LICENSE.log4j.txt', 1),
#  ('performance', 2),
#  ('non-blocking', 1),
#  ('license/LICENSE.aalto-xml.txt', 1),
#  ("'HPACK',", 1),
#  ('algorithm', 1),
#  ('license/LICENSE.hpack.txt', 1),
#  ("Lang',", 1),
#  ('utilities', 1),
#  ('java.lang', 1),
#  ('license/LICENSE.commons-lang.txt', 1),
#  ('https://commons.apache.org/proper/commons-lang/', 1),
#  ('1.4,', 1),
#  ('test', 3),
#  ('http://aspell.net/test/orig/batch0.tab.Copyright', 1),
#  ('2002', 2),
#  ('Atkinson', 2),
#  ('translated', 2),
#  ('php', 2),
#  ('http://stevemorse.org/phoneticinfo.htm', 2),
#  ('Original', 2),
#  ('Alexander', 2),
#  ('P.', 2),
#  ('2.6,', 1),
#  ('Spring', 2),
#  ('StringUtils.containsWhitespace())', 2),
#  ('Log4j', 1),
#  ('ResolverUtil.java', 1),
#  ('2005-2006', 2),
#  ('Fennell', 1),
#  ('Dumbster', 1),
#  ('SMTP', 1),
#  ('2004', 1),
#  ('Kitchen', 1),
#  ('Ramnivas', 1),
#  ('Hoeller,', 1),
#  ('Chris', 1),
#  ('6.1.26,', 1),
#  ('==============================================================', 2),
#  ('Mort', 2),
#  ('Bay', 2),
#  ('Consulting', 2),
#  ('Ltd.', 1),
#  ('Ltd', 1),
#  ('http://www.apache.org/licenses/LICENSE-2.0.html', 1),
#  ('1.0', 2),
#  ('http://www.eclipse.org/legal/epl-v10.html', 1),
#  ('artifacts', 11),
#  ('org.eclipse.jetty.orbit:javax.security.auth.message', 1),
#  ('CDDL', 4),
#  ('org.eclipse.jetty.orbit:javax.mail.glassfish', 1),
#  ('Oracle', 2),
#  ('exception.', 2),
#  ('javax.annotation:javax.annotation-api', 1),
#  ('used', 5),
#  ('negotiate', 1),
#  ('connections,', 1),
#  ('downloaded', 1),
#  ('module', 1),
#  ('These', 3),
#  ('replace/modify', 1),
#  ('modififications', 1),
#  ('GPL', 1),
#  ('v2', 1),
#  ('org.ow2.asm:asm-commons', 1),
#  ('licensed.', 3),
#  ('org.apache.taglibs:taglibs-standard-impl', 1),
#  ('Based', 1),
#  ('selected', 1),
#  ('org.mortbay.jasper:apache-jsp', 1),
#  ('org.apache.tomcat:tomcat-juli', 1),
#  ('org.apache.tomcat:tomcat-jsp-api', 1),
#  ('org.apache.tomcat:tomcat-jasper-el', 2),
#  ('org.apache.tomcat:tomcat-util-scan', 1),
#  ('org.apache.tomcat:tomcat-util', 1),
#  ('org.mortbay.jasper:apache-el', 1),
#  ('Mortbay', 1),
#  ('implements', 1),
#  ('way', 1),
#  ('cryptography', 1),
#  ('systems', 1),
#  ('password', 1),
#  ('protection.', 1),
#  ('Aki', 1),
#  ('Iris', 1),
#  ('Broeke,', 1),
#  ('Deville.', 1),
#  ('Permission', 1),
#  ('copy,', 1),
#  ('UnixCrypt', 1),
#  ('commercial', 1),
#  ('purposes', 1),
#  ('fee', 1),
#  ('copyright', 11),
#  ('appears', 1),
#  ('Snappy', 1),
#  ('Snappy:', 1),
#  ('http://hadoop.apache.org/', 1),
#  ('license)', 1),
#  ('statically', 1),
#  ('linked', 1),
#  ('libstdc++.', 1),
#  ('inclusion', 1),
#  ('RUntime', 1),
#  ('==', 20),
#  ('Saloranta', 3),
#  ('suite', 1),
#  ('Wysoker', 1),
#  ('Performance', 1),
#  ('usage', 1),
#  ('improvement', 1),
#  ('4(d)', 4),
#  ('Xerces', 4),
#  ('distribution.', 4),
#  ('1999-2007', 2),
#  ('Portions', 5),
#  ('originally', 9),
#  ('1999,', 4),
#  ('Microsystems.,', 2),
#  ('voluntary', 2),
#  ('iClick,', 2),
#  ('Inc.,', 2),
#  ('Jakarta', 3),
#  ('Digester', 1),
#  ('2001-2006', 1),
#  ('BeanUtils', 1),
#  ('ApacheDS', 2),
#  ('Kerberos', 1),
#  ('ASN.1', 1),
#  ('Curator', 3),
#  ('2011-2015', 3),
#  ('2015', 2),
#  ('#', 2),
#  ('Jackson', 4),
#  ('processor', 1),
#  ('high-performance,', 1),
#  ('Free/Open', 1),
#  ('Source', 2),
#  ('library.', 1),
#  ('was', 10),
#  ('(tatu.saloranta@iki.fi),', 1),
#  ('development', 3),
#  ('community', 2),
#  ('developers,', 1),
#  ('FasterXML.com.', 1),
#  ('Licensing', 1),
#  ('different', 2),
#  ('accompanying', 3),
#  ('LICENSE', 4),
#  ('possible', 2),
#  ('other', 7),
#  ('options,', 2),
#  ('FasterXML.com', 2),
#  ('Credits', 1),
#  ('contributors', 2),
#  ('(usually', 1),
#  ('distributions);', 1),
#  ('but', 5),
#  ('always', 1),
#  ('management', 1),
#  ('(SCM)', 1),
#  ('project', 7),
#  ('uses.', 1),
#  ('HttpCore', 1),
#  ('2005-2017', 1),
#  ('2001-2016', 1),
#  ('Orekit', 1),
#  ('CS', 2),
#  ('Systèmes', 2),
#  ("d'Information", 2),
#  ('(http://www.c-s.fr/)', 1),
#  ('log4j', 2),
#  ('2007', 2),
#  ('codec.', 1),
#  ('Credit', 1),
#  ('started', 1),
#  ('Ning,', 1),
#  ('official', 1),
#  ('Open', 1),
#  ('process', 1),
#  ('platform', 1),
#  ('backend,', 1),
#  ('after', 1),
#  ('initial', 1),
#  ('versions', 2),
#  ('Ning', 1),
#  ('community.', 1),
#  ('include:', 1),
#  ('Jon', 1),
#  ('Hartlaub', 1),
#  ('(first', 1),
#  ('streaming', 1),
#  ('Cedrik', 1),
#  ('Lime:', 1),
#  ('parallel', 1),
#  ('Various', 1),
#  ('members', 1),
#  ('reports,', 1),
#  ('suggested', 1),
#  ('fixes;', 1),
#  ('these', 1),
#  ('"VERSION.txt"', 1),
#  ('Style', 1),
#  ('server:', 1),
#  ('http://anonsvn.jboss.org/repos/common/common-logging-spi/', 1),
#  ('framework', 1),
#  ('implementation,', 1),
#  ('license/LICENSE.felix.txt', 1),
#  ('http://felix.apache.org/', 1),
#  ('Ivy', 2),
#  ('(TM)', 1),
#  ('2007-2014', 1),
#  ('Jayasoft', 1),
#  ('SARL', 1),
#  ('(http://www.jayasoft.fr/)', 1),
#  ('JCraft', 1),
#  ('JSch', 1),
#  ('related', 2),
#  ('ORC', 2),
#  ('Core', 3),
#  ('2001-2011', 1),
#  ('MapReduce', 1),
#  ('Parquet', 2),
#  ('2017', 5),
#  ('Vectors', 1),
#  ('Memory', 1),
#  ('Extensions', 1),
#  ('IO', 1),
#  ('Query', 1),
#  ('Extras', 1),
#  ('Companion', 1),
#  ('1.2.', 1),
#  ('individuals,', 5),
#  ('Erik', 2),
#  ('Bengtson', 2),
#  ('Joerg', 2),
#  ('Frantzius', 2),
#  ('Barry', 2),
#  ('Ullrich', 2),
#  ('Ezzio', 2),
#  ('Brendan', 2),
#  ('Tony', 2),
#  ('Anton', 1),
#  ('Troshin', 1),
#  ('(Timesten)', 1),
#  ('TJDO', 1),
#  ('(http://tjdo.sourceforge.net/).', 1),
#  ('Pool', 1),
#  ('1999-2009', 1),
#  ('(JDO)', 1),
#  ('HttpClient', 2),
#  ('Avatica', 1),
#  ('2012-2015', 3),
#  ('src/test/org/apache/commons/codec/language/DoubleMetaphoneTest.java', 1),
#  ('http://aspell.net/test/orig/batch0.tab.', 1),
#  ('=', 2),
#  ('Thomas', 1),
#  ('Marti', 1),
#  ('Mennemeier', 1),
#  ('Xuan', 1),
#  ('Baldauf', 1),
#  ('Sultan', 1),
#  ('Thrift', 1),
#  ('2006-2010', 1),
#  ('THIS', 1),
#  ('DIRECTLY.', 1),
#  ('IS', 1),
#  ('GENERATED', 1),
#  ('TARGET', 1),
#  ('TOP', 1),
#  ('build.xml', 1),
#  ('FILE.', 1),
#  ('2004-2015', 1),
#  ('International', 4),
#  ('Machines', 4),
#  ('Corporate', 2),
#  ('known', 2),
#  ('CLA".', 2),
#  ('notice(s)', 1),
#  ('now', 1),
#  ('placed', 1),
#  ('unaltered.', 1),
#  ('National', 1),
#  ('Institute', 2),
#  ('Standards', 1),
#  ('agency', 1),
#  ('United', 1),
#  ('States', 1),
#  ('adapted', 2),
#  ('Acknowledgment', 1),
#  ('Redistribution', 1),
#  ('JDBC', 2),
#  ('java/stubs/jdbc3)', 1),
#  ('Harmony', 5),
#  ('project.', 4),
#  ('covers', 3),
#  ('Intel', 1),
#  ('Main', 1),
#  ('I.', 1),
#  ('Alliance', 4),
#  ('(http://www.osgi.org/).', 2),
#  ('http://kxml.sourceforge.net.', 1),
#  ('Haustein,', 1),
#  ('Oberhausen,', 1),
#  ('Germany.', 1),
#  ('II.', 1),
#  ('Summary', 1),
#  ('jar', 3),
#  ('2013', 1),
#  ('Includes', 1),
#  ('limited', 3),
#  ('Ant', 1),
#  ('ICU4J,', 1),
#  ('1995-2008', 1),
#  ('others', 1),
#  ('analysis/icu/src/data)', 1),
#  ('Unicode', 4),
#  ('Character', 2),
#  ('details.', 2),
#  ('BSD-licensed,', 1),
#  ('Anders', 1),
#  ('Møller.', 1),
#  ('http://www.brics.dk/automaton/', 1),
#  ('levenshtein', 1),
#  ('automata', 1),
#  ('generated', 1),
#  ('moman/finenight', 1),
#  ('Jean-Philippe', 1),
#  ('http://sites.google.com/site/rrettesite/moman', 1),
#  ('class', 3),
#  ('Code', 1),
#  ('Prettify', 1),
#  ('(junit-4.10)', 1),
#  ('v.', 1),
#  ('http://junit.sourceforge.net/cpl-v10.html', 1),
#  ('g', 1),
#  ('Package', 1),
#  ('License:', 1),
#  ('(http://www.opensource.org/licenses/bsd-license.php)', 1),
#  ('stemmers', 2),
#  ('Porter', 2),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/snowball', 1),
#  ('full', 1),
#  ('http://snowball.tartarus.org/', 1),
#  ('KStem', 1),
#  ('stemmer', 1),
#  ('Krovetz', 1),
#  ('Sergio', 1),
#  ('(CIIR-UMass', 1),
#  ('Amherst)', 1),
#  ('Arabic,Persian,Romanian,Bulgarian,', 1),
#  ('analyzers', 1),
#  ('(common)', 2),
#  ('default', 2),
#  ('Jacques', 2),
#  ('Savoy.', 1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/fa/stopwords.txt,',
#   1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/ro/stopwords.txt,',
#   1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/bg/stopwords.txt,',
#   1),
#  ('http://members.unine.ch/jacques.savoy/clef/index.html.', 1),
#  ('Swedish', 1),
#  ('reference', 1),
#  ('Savoy', 1),
#  ('Ljiljana', 1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/de/GermanLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/de/GermanMinimalStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/es/SpanishLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/hu/HungarianLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/pt/PortugueseLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/ru/RussianLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/sv/SwedishLightStemmer.java',
#   1),
#  ('Stempel', 1),
#  ('(stempel)', 2),
#  ('Egothor', 1),
#  ('Leo', 1),
#  ('Edmond', 1),
#  ('Nolan.', 1),
#  ('Polish', 3),
#  ('Carrot2', 1),
#  ('stempel/src/resources/org/apache/lucene/analysis/pl/stopwords.txt.', 1),
#  ('http://project.carrot2.org/license.html.', 1),
#  ('modules/analysis/common/src/test/)', 1),
#  ('Morfologik', 2),
#  ('Marcin', 1),
#  ('dictionary', 4),
#  ('alia)', 1),
#  ('Creative', 1),
#  ('Morfologic', 1),
#  ('(SGJP)', 1),
#  ('(http://sgjp.pl/morfeusz/)', 1),
#  ('Morphological', 1),
#  ('Analyzer', 1),
#  ('Integration', 1),
#  ('mecab-ipadic-2.7.0-20070801', 2),
#  ('http://jaist.dl.sourceforge.net/project/mecab/mecab-ipadic/2.7.0-20070801/mecab-ipadic-2.7.0-20070801.tar.gz',
#   1),
#  ('Nara', 1),
#  ('Science', 1),
#  ('(NAIST),', 1),
#  ('regard', 1),
#  ('implied', 1),
#  ('no', 2),
#  ('special,', 2),
#  ('indirect', 1),
#  ('consequential', 2),
#  ('whatsoever', 2),
#  ('resulting', 1),
#  ('loss', 1),
#  ('action', 1),
#  ('negligence', 1),
#  ('tortuous', 1),
#  ('out', 3),
#  ('connection', 2),
#  ('large', 1),
#  ('originate', 1),
#  ('Free', 2),
#  ('conditions', 1),
#  ('applies', 1),
#  ('current', 1),
#  ('Each', 3),
#  ('User', 2),
#  ('freely', 1),
#  ('Program,', 2),
#  ('third', 2),
#  ('parties,', 1),
#  ('PROVIDED', 1),
#  ('("NO', 1),
#  ('WARRANTY")', 1),
#  ('ALWAYS', 1),
#  ('appear', 1),
#  ('on,', 1),
#  ('substantially', 1),
#  ('set', 2),
#  ('neither', 2),
#  ('contravene', 1),
#  ('countries', 1),
#  ('itself.', 1),
#  ('NO', 1),
#  ('basis', 1),
#  ('research', 1),
#  ('during', 2),
#  ('basis.', 1),
#  ('whatsoever,', 1),
#  ('express,', 1),
#  ('otherwise.', 1),
#  ('term', 2),
#  ('performance,', 1),
#  ('particular', 1),
#  ('violation', 1),
#  ('right', 1),
#  ('party.', 1),
#  ('understand,', 1),
#  ('deemed', 2),
#  ('there', 1),
#  ('accordingly,', 1),
#  ('entire', 1),
#  ('risk', 1),
#  ('assumed', 1),
#  ('Therefore,', 1),
#  ('participated', 1),
#  ('respective', 1),
#  ('officers', 1),
#  ('damages,', 2),
#  ('incidental', 1),
#  ('material', 1),
#  ('result', 1),
#  ('program,', 2),
#  ('regardless', 1),
#  ('knowledge', 1),
#  ('possibility', 1),
#  ('foregoing', 1),
#  ('his', 1),
#  ('her', 1),
#  ('"use"', 1),
#  ('copying', 1),
#  ('production', 1),
#  ('where', 1),
#  ('person,', 2),
#  ('entity', 1),
#  ('than', 1),
#  ('grants', 1),
#  ('independently', 1),
#  ('exempted', 1),
#  ('above', 1),
#  ('far', 1),
#  ('concerned.', 1),
#  ('project,', 1),
#  ('Kryo.', 1),
#  ('2012', 1),
#  ('Dependencies:', 1),
#  ('2.17', 1),
#  ('3-Clause', 1),
#  ('http://code.google.com/p/kryo', 1),
#  ('1.7', 1),
#  ('V2.0', 1),
#  ('algorithms', 1),
#  ('Proximal.scala', 1),
#  ('details)', 1),
#  ('Debasish', 3),
#  ('Das', 3),
#  ('QuadraticMinimizer', 1),
#  ('breeze.optimize.proximal', 2),
#  ('NonlinearMinimizer', 1),
#  ('2015,', 1),
#  ('Solr', 1),
#  ('Mahout', 1),
#  ('Copyright', 85),
#  ('and', 81),
#  ('onwards', 1),
#  ('Software', 77),
#  ('Foundation.', 2),
#  ('This', 69),
#  ('product', 72),
#  ('includes', 31),
#  ('software', 41),
#  ('Foundation', 70),
#  ('(http://www.apache.org/).', 6),
#  ('Control', 2),
#  ('Notice', 2),
#  ('---------------------', 1),
#  ('cryptographic', 3),
#  ('which', 40),
#  ('you', 3),
#  ('currently', 3),
#  ('on', 35),
#  ('the', 158),
#  ('import,', 2),
#  ('re-export', 2),
#  ('to', 37),
#  ('another', 1),
#  ('encryption', 4),
#  ('BEFORE', 1),
#  ('any', 18),
#  ('please', 2),
#  ('your', 1),
#  ('regulations', 2),
#  ('concerning', 1),
#  ('or', 39),
#  ('see', 5),
#  ('if', 3),
#  ('permitted.', 1),
#  ('See', 9),
#  ('for', 34),
#  ('U.S.', 1),
#  ('Government', 1),
#  ('Department', 2),
#  ('Commerce,', 2),
#  ('Bureau', 1),
#  ('has', 19),
#  ('classified', 1),
#  ('(ECCN)', 1),
#  ('5D002.C.1,', 1),
#  ('information', 2),
#  ('performing', 1),
#  ('with', 19),
#  ('asymmetric', 1),
#  ('manner', 1),
#  ('makes', 2),
#  ('it', 2),
#  ('under', 27),
#  ('License', 37),
#  ('Exception', 1),
#  ('Technology', 3),
#  ('Unrestricted', 1),
#  ('(TSU)', 1),
#  ('(see', 2),
#  ('Regulations,', 1),
#  ('Section', 2),
#  ('740.13)', 1),
#  ('object', 1),
#  ('code', 12),
#  ('included', 6),
#  ('Commons', 23),
#  ('Crypto', 2),
#  ('data', 13),
#  ('across', 1),
#  ('between', 1),
#  ('services.', 1),
#  ('------------------------------------------------------------------', 2),
#  ('file', 13),
#  ('corresponding', 6),
#  ('section', 6),
#  ('License,', 6),
#  ('Version', 6),
#  ('2.0,', 6),
#  ('case', 6),
#  ('Beeline', 1),
#  ('Avro', 3),
#  ('2009-2014', 3),
#  ('contains', 20),
#  ('by', 66),
#  ('authors', 1),
#  ('identified', 1),
#  ('files;', 1),
#  ('such', 7),
#  ('missing', 1),
#  ('been', 8),
#  ('Tatu', 5),
#  ('For', 3),
#  ('(generally', 1),
#  ('people', 1),
#  ('who', 1),
#  ('problems)', 1),
#  ('Compress', 2),
#  ('2002-2012', 3),
#  ('Mapred', 1),
#  ('API', 5),
#  ('IPC', 1),
#  ('2006-2013', 1),
#  ('Joe', 1),
#  ('Walnes,', 1),
#  ('Henri', 1),
#  ('Tremblay,', 1),
#  ('Mesquita', 1),
#  ('::', 1),
#  ('5', 1),
#  ('shaded', 1),
#  ('(repackaged)', 1),
#  ('2005-2015', 1),
#  ('Consortium', 1),
#  ('bundles', 9),
#  ('binaries', 9),
#  ('notices:', 9),
#  ('<dain@iq80.com>', 1),
#  ('http://fusesource.com', 2),
#  ('org.fusesource.hawtjni:hawtjni-runtime', 1),
#  ('its', 3),
#  ('affiliates.', 1),
#  ('Gson', 1),
#  ('Netty', 5),
#  ('web', 1),
#  ('http://netty.io/', 1),
#  ('licenses', 1),
#  ('not', 6),
#  ('except', 1),
#  ('You', 1),
#  ('a', 46),
#  ('copy', 1),
#  ('http://www.apache.org/licenses/LICENSE-2.0', 2),
#  ('Unless', 1),
#  ('required', 1),
#  ('applicable', 1),
#  ('agreed', 3),
#  ('writing,', 2),
#  ('distributed', 10),
#  ('WITHOUT', 1),
#  ('WARRANTIES', 1),
#  ('OR', 1),
#  ('ANY', 1),
#  ('either', 2),
#  ('express', 1),
#  ('implied.', 1),
#  ('governing', 1),
#  ('permissions', 1),
#  ('Also,', 1),
#  ('each', 1),
#  ('file,', 3),
#  ('located', 1),
#  ('license', 2),
#  ('terms', 4),
#  ('that', 13),
#  ('on.', 1),
#  ('Framework', 2),
#  ('from', 34),
#  ('works', 1),
#  ('EG,', 1),
#  ('Doug', 1),
#  ('T.', 1),
#  ('http://gee.cs.oswego.edu/cgi-bin/viewcvs.cgi/jsr166/', 1),
#  ('Robert', 1),
#  ("Harder's", 1),
#  ('Base64', 1),
#  ('can', 32),
#  ('be', 43),
#  ('license/LICENSE.base64.txt', 1),
#  ('portion', 12),
#  ('WebSocket', 2),
#  ('license/LICENSE.webbit.txt', 1),
#  ('https://github.com/joewalnes/webbit', 1),
#  ('written', 9),
#  ('Bloch', 1),
#  ("'Apache", 6),
#  ("Harmony',", 1),
#  ('SE,', 1),
#  ('(Apache', 12),
#  ('2.0)', 11),
#  ('http://archive.apache.org/dist/harmony/', 1),
#  ('ASL2', 4),
#  ('AbstractNodeQueue,', 1),
#  ("Vyukov's", 1),
#  ('queue.', 1),
#  ('https://github.com/akka/akka/blob/wip-2.2.3-for-scala-2.11/akka-actor/src/main/java/akka/dispatch/AbstractNodeQueue.java',
#   1),
#  ("'jbzip2',", 1),
#  ('bzip2', 1),
#  ('compression', 6),
#  ('J.', 1),
#  ('Francis.', 1),
#  ('https://code.google.com/p/jbzip2/', 1),
#  ("'libdivsufsort',", 1),
#  ('suffix', 1),
#  ('Burrows-Wheeler', 1),
#  ('string', 2),
#  ('Mori.', 1),
#  ('license/LICENSE.libdivsufsort.txt', 1),
#  ('https://code.google.com/p/libdivsufsort/', 1),
#  ("Wakart's", 1),
#  ('Concurrency', 1),
#  ('Tools', 1),
#  ('(ASL2', 1),
#  ('https://github.com/JCTools/JCTools', 1),
#  ('optionally', 17),
#  ("'JZlib',", 2),
#  ('pure', 2),
#  ('http://www.jcraft.com/jzlib/', 2),
#  ("'Compress-LZF',", 1),
#  ('decoding', 1),
#  ('license/LICENSE.compress-lzf.txt', 1),
#  ("'lz4',", 1),
#  ('Grand.', 1),
#  ('license/LICENSE.lz4.txt', 1),
#  ('https://github.com/jpountz/lz4-java', 1),
#  ("'lzma-java',", 1),
#  ('license/LICENSE.lzma-java.txt', 1),
#  ('https://github.com/jponge/lzma-java', 1),
#  ("'jfastlz',", 1),
#  ('port', 1),
#  ('FastLZ', 1),
#  ('William', 1),
#  ('https://code.google.com/p/jfastlz/', 1),
#  ("'Protocol", 2),
#  ('BSD', 8),
#  ('temporary', 1),
#  ('X.509', 1),
#  ('certificate', 1),
#  ('does', 1),
#  ('equivalent', 1),
#  ('functionality.', 1),
#  ('http://www.bouncycastle.org/', 1),
#  ('Inc,', 1),
#  ('http://code.google.com/p/snappy/', 2),
#  ("Marshalling',", 1),
#  ('API,', 2),
#  ('LGPL', 3),
#  ('http://www.jboss.org/jbossmarshalling', 1),
#  ('framework,', 5),
#  ('http://code.google.com/p/caliper/', 1),
#  ('license/LICENSE.commons-logging.txt', 1),
#  ('http://commons.apache.org/logging/', 1),
#  ('http://logging.apache.org/log4j/', 1),
#  ("'Aalto", 1),
#  ("XML',", 1),
#  ('ultra-high', 1),
#  ('XML', 1),
#  ('processor,', 1),
#  ('http://wiki.fasterxml.com/AaltoHome', 1),
#  ...]

# %%
lines.flatMap(lambda x: x.split(" ")).map(lambda x: (x, 1)).reduceByKey(lambda x, y: x+y).collect()
# Out:
# [('Apache', 147),
#  ('Spark', 1),
#  ('2014', 5),
#  ('The', 129),
#  ('', 1257),
#  ('developed', 35),
#  ('at', 21),
#  ('Export', 3),
#  ('distribution', 15),
#  ('software.', 3),
#  ('country', 1),
#  ('in', 35),
#  ('reside', 3),
#  ('may', 9),
#  ('have', 6),
#  ('restrictions', 1),
#  ('possession,', 2),
#  ('use,', 5),
#  ('and/or', 3),
#  ('country,', 1),
#  ('of', 106),
#  ('using', 3),
#  ('software,', 4),
#  ('check', 1),
#  ("country's", 1),
#  ('laws,', 1),
#  ('policies', 1),
#  ('this', 28),
#  ('is', 42),
#  ('<http://www.wassenaar.org/>', 1),
#  ('more', 7),
#  ('information.', 1),
#  ('Industry', 1),
#  ('Security', 1),
#  ('(BIS),', 1),
#  ('as', 19),
#  ('Commodity', 1),
#  ('Number', 1),
#  ('security', 1),
#  ('functions', 1),
#  ('algorithms.', 1),
#  ('form', 4),
#  ('eligible', 1),
#  ('export', 1),
#  ('ENC', 1),
#  ('exception', 1),
#  ('BIS', 1),
#  ('Administration', 1),
#  ('both', 3),
#  ('source', 15),
#  ('code.', 1),
#  ('following', 25),
#  ('provides', 2),
#  ('details', 3),
#  ('software:', 1),
#  ('uses', 3),
#  ('(https://commons.apache.org/proper/commons-crypto/)', 1),
#  ('support', 2),
#  ('authentication,', 1),
#  ('decryption', 1),
#  ('sent', 1),
#  ('network', 1),
#  ('//', 4),
#  ('NOTICE', 6),
#  ('4d', 2),
#  ('Hive', 5),
#  ('2016', 6),
#  ('only', 1),
#  ('specific', 3),
#  ('components,', 1),
#  ('notes', 1),
#  ('are', 20),
#  ('files', 6),
#  ('created', 7),
#  ('Saloranta.', 2),
#  ('additional', 2),
#  ('credits', 1),
#  ('reported', 1),
#  ('CREDITS', 2),
#  ('file.', 4),
#  ('Objenesis', 1),
#  ('Leonardo', 1),
#  ('XBean', 1),
#  ('ASM', 1),
#  ('--------------------------------------', 1),
#  ('OW2', 3),
#  ('(http://asm.ow2.org/)', 1),
#  ('binary', 10),
#  ('org.iq80.leveldb:leveldb-api', 1),
#  ('(https://github.com/dain/leveldb),', 1),
#  ('*', 139),
#  ('2011', 3),
#  ('Dain', 1),
#  ('Sundstrom', 1),
#  ('FuseSource', 2),
#  ('Corp.', 3),
#  ('(https://github.com/fusesource/hawtjni),', 1),
#  ('Progress', 1),
#  ('Corporation', 6),
#  ('subsidiaries', 1),
#  ('IBM', 4),
#  ('others.', 1),
#  ('2.2.4,', 1),
#  ('Project', 4),
#  ('=================', 1),
#  ('Please', 1),
#  ('visit', 1),
#  ('site', 1),
#  ('information:', 1),
#  ('version', 7),
#  ('2.0', 9),
#  ('(the', 1),
#  ('"License");', 1),
#  ('use', 5),
#  ('compliance', 1),
#  ('License.', 4),
#  ('obtain', 1),
#  ('at:', 30),
#  ('law', 1),
#  ('an', 14),
#  ('"AS', 1),
#  ('IS"', 1),
#  ('BASIS,', 1),
#  ('CONDITIONS', 1),
#  ('OF', 1),
#  ('KIND,', 1),
#  ('language', 1),
#  ('limitations', 1),
#  ('refer', 1),
#  ('LICENSE.<component>.txt', 1),
#  ("'license'", 1),
#  ('directory', 1),
#  ('components', 3),
#  ('depends', 18),
#  ('-------------------------------------------------------------------------------',
#   1),
#  ('extensions', 2),
#  ('Java', 19),
#  ('Collections', 2),
#  ('derived', 4),
#  ('JSR-166', 1),
#  ('Lea,', 1),
#  ('Jason', 2),
#  ('Greene:', 1),
#  ('LICENSE:', 28),
#  ('license/LICENSE.jsr166y.txt', 1),
#  ('(Public', 4),
#  ('Domain)', 4),
#  ('HOMEPAGE:', 27),
#  ('http://viewvc.jboss.org/cgi-bin/viewvc.cgi/jbosscache/experimental/jsr166/',
#   1),
#  ('modified', 17),
#  ('Public', 4),
#  ('Domain', 1),
#  ('Encoder', 1),
#  ('Decoder,', 1),
#  ('obtained', 31),
#  ('http://iharder.sourceforge.net/current/java/base64/', 1),
#  ("'Webbit',", 2),
#  ('event', 3),
#  ('based', 7),
#  ('HTTP', 2),
#  ('server,', 1),
#  ('(BSD', 3),
#  ('License)', 12),
#  ("'SLF4J',", 2),
#  ('simple', 4),
#  ('logging', 6),
#  ('facade', 2),
#  ('Java,', 4),
#  ('license/LICENSE.slf4j.txt', 1),
#  ('(MIT', 5),
#  ('http://www.slf4j.org/', 1),
#  ("'ArrayDeque',", 1),
#  ('Josh', 1),
#  ('Google,', 3),
#  ('Inc:', 1),
#  ('license/LICENSE.deque.txt', 1),
#  ('open', 3),
#  ('license/LICENSE.harmony.txt', 1),
#  ('Roland', 3),
#  ("Kuhn's", 1),
#  ('Dmitriy', 1),
#  ('non-intrusive', 1),
#  ('MPSC', 1),
#  ('It', 11),
#  ('license/LICENSE.abstractnodequeue.txt', 1),
#  ('decompression', 4),
#  ('library', 10),
#  ('Matthew', 1),
#  ('license/LICENSE.jbzip2.txt', 1),
#  ('C', 1),
#  ('construct', 1),
#  ('array', 1),
#  ('transformed', 1),
#  ('input', 1),
#  ('constant-size', 1),
#  ('alphabet', 1),
#  ('Yuta', 1),
#  ('Nitsan', 1),
#  ("'JCTools',", 1),
#  ('JVM,', 1),
#  ('license/LICENSE.jctools.txt', 1),
#  ('re-implementation', 2),
#  ('zlib', 2),
#  ('license/LICENSE.jzlib.txt', 2),
#  ('style', 2),
#  ('encoding', 1),
#  ('LZF', 4),
#  ('format,', 4),
#  ('https://github.com/ning/compress', 1),
#  ('LZ4', 1),
#  ('Adrien', 1),
#  ('LZMA', 1),
#  ('library,', 2),
#  ('Kinney.', 1),
#  ('license/LICENSE.jfastlz.txt', 1),
#  ("Buffers',", 2),
#  ("Google's", 3),
#  ('interchange', 2),
#  ('license/LICENSE.protobuf.txt', 1),
#  ('(New', 3),
#  ('http://code.google.com/p/protobuf/', 1),
#  ("'Bouncy", 1),
#  ('Castle', 1),
#  ("APIs'", 1),
#  ('generate', 1),
#  ('self-signed', 1),
#  ('when', 2),
#  ('JVM', 1),
#  ('provide', 1),
#  ('license/LICENSE.bouncycastle.txt', 1),
#  ("'Snappy',", 1),
#  ('produced', 5),
#  ('Google', 5),
#  ('license/LICENSE.snappy.txt', 1),
#  ("'JBoss", 2),
#  ('alternative', 1),
#  ('serialization', 1),
#  ('license/LICENSE.jboss-marshalling.txt', 1),
#  ('(GNU', 2),
#  ('2.1)', 2),
#  ("'Caliper',", 1),
#  ('micro-', 1),
#  ('benchmarking', 1),
#  ('license/LICENSE.caliper.txt', 1),
#  ("Logging',", 2),
#  ("Log4J',", 2),
#  ('license/LICENSE.log4j.txt', 1),
#  ('performance', 2),
#  ('non-blocking', 1),
#  ('license/LICENSE.aalto-xml.txt', 1),
#  ("'HPACK',", 1),
#  ('algorithm', 1),
#  ('license/LICENSE.hpack.txt', 1),
#  ("Lang',", 1),
#  ('utilities', 1),
#  ('java.lang', 1),
#  ('license/LICENSE.commons-lang.txt', 1),
#  ('https://commons.apache.org/proper/commons-lang/', 1),
#  ('1.4,', 1),
#  ('test', 3),
#  ('http://aspell.net/test/orig/batch0.tab.Copyright', 1),
#  ('2002', 2),
#  ('Atkinson', 2),
#  ('translated', 2),
#  ('php', 2),
#  ('http://stevemorse.org/phoneticinfo.htm', 2),
#  ('Original', 2),
#  ('Alexander', 2),
#  ('P.', 2),
#  ('2.6,', 1),
#  ('Spring', 2),
#  ('StringUtils.containsWhitespace())', 2),
#  ('Log4j', 1),
#  ('ResolverUtil.java', 1),
#  ('2005-2006', 2),
#  ('Fennell', 1),
#  ('Dumbster', 1),
#  ('SMTP', 1),
#  ('2004', 1),
#  ('Kitchen', 1),
#  ('Ramnivas', 1),
#  ('Hoeller,', 1),
#  ('Chris', 1),
#  ('6.1.26,', 1),
#  ('==============================================================', 2),
#  ('Mort', 2),
#  ('Bay', 2),
#  ('Consulting', 2),
#  ('Ltd.', 1),
#  ('Ltd', 1),
#  ('http://www.apache.org/licenses/LICENSE-2.0.html', 1),
#  ('1.0', 2),
#  ('http://www.eclipse.org/legal/epl-v10.html', 1),
#  ('artifacts', 11),
#  ('org.eclipse.jetty.orbit:javax.security.auth.message', 1),
#  ('CDDL', 4),
#  ('org.eclipse.jetty.orbit:javax.mail.glassfish', 1),
#  ('Oracle', 2),
#  ('exception.', 2),
#  ('javax.annotation:javax.annotation-api', 1),
#  ('used', 5),
#  ('negotiate', 1),
#  ('connections,', 1),
#  ('downloaded', 1),
#  ('module', 1),
#  ('These', 3),
#  ('replace/modify', 1),
#  ('modififications', 1),
#  ('GPL', 1),
#  ('v2', 1),
#  ('org.ow2.asm:asm-commons', 1),
#  ('licensed.', 3),
#  ('org.apache.taglibs:taglibs-standard-impl', 1),
#  ('Based', 1),
#  ('selected', 1),
#  ('org.mortbay.jasper:apache-jsp', 1),
#  ('org.apache.tomcat:tomcat-juli', 1),
#  ('org.apache.tomcat:tomcat-jsp-api', 1),
#  ('org.apache.tomcat:tomcat-jasper-el', 2),
#  ('org.apache.tomcat:tomcat-util-scan', 1),
#  ('org.apache.tomcat:tomcat-util', 1),
#  ('org.mortbay.jasper:apache-el', 1),
#  ('Mortbay', 1),
#  ('implements', 1),
#  ('way', 1),
#  ('cryptography', 1),
#  ('systems', 1),
#  ('password', 1),
#  ('protection.', 1),
#  ('Aki', 1),
#  ('Iris', 1),
#  ('Broeke,', 1),
#  ('Deville.', 1),
#  ('Permission', 1),
#  ('copy,', 1),
#  ('UnixCrypt', 1),
#  ('commercial', 1),
#  ('purposes', 1),
#  ('fee', 1),
#  ('copyright', 11),
#  ('appears', 1),
#  ('Snappy', 1),
#  ('Snappy:', 1),
#  ('http://hadoop.apache.org/', 1),
#  ('license)', 1),
#  ('statically', 1),
#  ('linked', 1),
#  ('libstdc++.', 1),
#  ('inclusion', 1),
#  ('RUntime', 1),
#  ('==', 20),
#  ('Saloranta', 3),
#  ('suite', 1),
#  ('Wysoker', 1),
#  ('Performance', 1),
#  ('usage', 1),
#  ('improvement', 1),
#  ('4(d)', 4),
#  ('Xerces', 4),
#  ('distribution.', 4),
#  ('1999-2007', 2),
#  ('Portions', 5),
#  ('originally', 9),
#  ('1999,', 4),
#  ('Microsystems.,', 2),
#  ('voluntary', 2),
#  ('iClick,', 2),
#  ('Inc.,', 2),
#  ('Jakarta', 3),
#  ('Digester', 1),
#  ('2001-2006', 1),
#  ('BeanUtils', 1),
#  ('ApacheDS', 2),
#  ('Kerberos', 1),
#  ('ASN.1', 1),
#  ('Curator', 3),
#  ('2011-2015', 3),
#  ('2015', 2),
#  ('#', 2),
#  ('Jackson', 4),
#  ('processor', 1),
#  ('high-performance,', 1),
#  ('Free/Open', 1),
#  ('Source', 2),
#  ('library.', 1),
#  ('was', 10),
#  ('(tatu.saloranta@iki.fi),', 1),
#  ('development', 3),
#  ('community', 2),
#  ('developers,', 1),
#  ('FasterXML.com.', 1),
#  ('Licensing', 1),
#  ('different', 2),
#  ('accompanying', 3),
#  ('LICENSE', 4),
#  ('possible', 2),
#  ('other', 7),
#  ('options,', 2),
#  ('FasterXML.com', 2),
#  ('Credits', 1),
#  ('contributors', 2),
#  ('(usually', 1),
#  ('distributions);', 1),
#  ('but', 5),
#  ('always', 1),
#  ('management', 1),
#  ('(SCM)', 1),
#  ('project', 7),
#  ('uses.', 1),
#  ('HttpCore', 1),
#  ('2005-2017', 1),
#  ('2001-2016', 1),
#  ('Orekit', 1),
#  ('CS', 2),
#  ('Systèmes', 2),
#  ("d'Information", 2),
#  ('(http://www.c-s.fr/)', 1),
#  ('log4j', 2),
#  ('2007', 2),
#  ('codec.', 1),
#  ('Credit', 1),
#  ('started', 1),
#  ('Ning,', 1),
#  ('official', 1),
#  ('Open', 1),
#  ('process', 1),
#  ('platform', 1),
#  ('backend,', 1),
#  ('after', 1),
#  ('initial', 1),
#  ('versions', 2),
#  ('Ning', 1),
#  ('community.', 1),
#  ('include:', 1),
#  ('Jon', 1),
#  ('Hartlaub', 1),
#  ('(first', 1),
#  ('streaming', 1),
#  ('Cedrik', 1),
#  ('Lime:', 1),
#  ('parallel', 1),
#  ('Various', 1),
#  ('members', 1),
#  ('reports,', 1),
#  ('suggested', 1),
#  ('fixes;', 1),
#  ('these', 1),
#  ('"VERSION.txt"', 1),
#  ('Style', 1),
#  ('server:', 1),
#  ('http://anonsvn.jboss.org/repos/common/common-logging-spi/', 1),
#  ('framework', 1),
#  ('implementation,', 1),
#  ('license/LICENSE.felix.txt', 1),
#  ('http://felix.apache.org/', 1),
#  ('Ivy', 2),
#  ('(TM)', 1),
#  ('2007-2014', 1),
#  ('Jayasoft', 1),
#  ('SARL', 1),
#  ('(http://www.jayasoft.fr/)', 1),
#  ('JCraft', 1),
#  ('JSch', 1),
#  ('related', 2),
#  ('ORC', 2),
#  ('Core', 3),
#  ('2001-2011', 1),
#  ('MapReduce', 1),
#  ('Parquet', 2),
#  ('2017', 5),
#  ('Vectors', 1),
#  ('Memory', 1),
#  ('Extensions', 1),
#  ('IO', 1),
#  ('Query', 1),
#  ('Extras', 1),
#  ('Companion', 1),
#  ('1.2.', 1),
#  ('individuals,', 5),
#  ('Erik', 2),
#  ('Bengtson', 2),
#  ('Joerg', 2),
#  ('Frantzius', 2),
#  ('Barry', 2),
#  ('Ullrich', 2),
#  ('Ezzio', 2),
#  ('Brendan', 2),
#  ('Tony', 2),
#  ('Anton', 1),
#  ('Troshin', 1),
#  ('(Timesten)', 1),
#  ('TJDO', 1),
#  ('(http://tjdo.sourceforge.net/).', 1),
#  ('Pool', 1),
#  ('1999-2009', 1),
#  ('(JDO)', 1),
#  ('HttpClient', 2),
#  ('Avatica', 1),
#  ('2012-2015', 3),
#  ('src/test/org/apache/commons/codec/language/DoubleMetaphoneTest.java', 1),
#  ('http://aspell.net/test/orig/batch0.tab.', 1),
#  ('=', 2),
#  ('Thomas', 1),
#  ('Marti', 1),
#  ('Mennemeier', 1),
#  ('Xuan', 1),
#  ('Baldauf', 1),
#  ('Sultan', 1),
#  ('Thrift', 1),
#  ('2006-2010', 1),
#  ('THIS', 1),
#  ('DIRECTLY.', 1),
#  ('IS', 1),
#  ('GENERATED', 1),
#  ('TARGET', 1),
#  ('TOP', 1),
#  ('build.xml', 1),
#  ('FILE.', 1),
#  ('2004-2015', 1),
#  ('International', 4),
#  ('Machines', 4),
#  ('Corporate', 2),
#  ('known', 2),
#  ('CLA".', 2),
#  ('notice(s)', 1),
#  ('now', 1),
#  ('placed', 1),
#  ('unaltered.', 1),
#  ('National', 1),
#  ('Institute', 2),
#  ('Standards', 1),
#  ('agency', 1),
#  ('United', 1),
#  ('States', 1),
#  ('adapted', 2),
#  ('Acknowledgment', 1),
#  ('Redistribution', 1),
#  ('JDBC', 2),
#  ('java/stubs/jdbc3)', 1),
#  ('Harmony', 5),
#  ('project.', 4),
#  ('covers', 3),
#  ('Intel', 1),
#  ('Main', 1),
#  ('I.', 1),
#  ('Alliance', 4),
#  ('(http://www.osgi.org/).', 2),
#  ('http://kxml.sourceforge.net.', 1),
#  ('Haustein,', 1),
#  ('Oberhausen,', 1),
#  ('Germany.', 1),
#  ('II.', 1),
#  ('Summary', 1),
#  ('jar', 3),
#  ('2013', 1),
#  ('Includes', 1),
#  ('limited', 3),
#  ('Ant', 1),
#  ('ICU4J,', 1),
#  ('1995-2008', 1),
#  ('others', 1),
#  ('analysis/icu/src/data)', 1),
#  ('Unicode', 4),
#  ('Character', 2),
#  ('details.', 2),
#  ('BSD-licensed,', 1),
#  ('Anders', 1),
#  ('Møller.', 1),
#  ('http://www.brics.dk/automaton/', 1),
#  ('levenshtein', 1),
#  ('automata', 1),
#  ('generated', 1),
#  ('moman/finenight', 1),
#  ('Jean-Philippe', 1),
#  ('http://sites.google.com/site/rrettesite/moman', 1),
#  ('class', 3),
#  ('Code', 1),
#  ('Prettify', 1),
#  ('(junit-4.10)', 1),
#  ('v.', 1),
#  ('http://junit.sourceforge.net/cpl-v10.html', 1),
#  ('g', 1),
#  ('Package', 1),
#  ('License:', 1),
#  ('(http://www.opensource.org/licenses/bsd-license.php)', 1),
#  ('stemmers', 2),
#  ('Porter', 2),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/snowball', 1),
#  ('full', 1),
#  ('http://snowball.tartarus.org/', 1),
#  ('KStem', 1),
#  ('stemmer', 1),
#  ('Krovetz', 1),
#  ('Sergio', 1),
#  ('(CIIR-UMass', 1),
#  ('Amherst)', 1),
#  ('Arabic,Persian,Romanian,Bulgarian,', 1),
#  ('analyzers', 1),
#  ('(common)', 2),
#  ('default', 2),
#  ('Jacques', 2),
#  ('Savoy.', 1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/fa/stopwords.txt,',
#   1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/ro/stopwords.txt,',
#   1),
#  ('analysis/common/src/resources/org/apache/lucene/analysis/bg/stopwords.txt,',
#   1),
#  ('http://members.unine.ch/jacques.savoy/clef/index.html.', 1),
#  ('Swedish', 1),
#  ('reference', 1),
#  ('Savoy', 1),
#  ('Ljiljana', 1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/de/GermanLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/de/GermanMinimalStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/es/SpanishLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/hu/HungarianLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/pt/PortugueseLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/ru/RussianLightStemmer.java',
#   1),
#  ('analysis/common/src/java/org/apache/lucene/analysis/sv/SwedishLightStemmer.java',
#   1),
#  ('Stempel', 1),
#  ('(stempel)', 2),
#  ('Egothor', 1),
#  ('Leo', 1),
#  ('Edmond', 1),
#  ('Nolan.', 1),
#  ('Polish', 3),
#  ('Carrot2', 1),
#  ('stempel/src/resources/org/apache/lucene/analysis/pl/stopwords.txt.', 1),
#  ('http://project.carrot2.org/license.html.', 1),
#  ('modules/analysis/common/src/test/)', 1),
#  ('Morfologik', 2),
#  ('Marcin', 1),
#  ('dictionary', 4),
#  ('alia)', 1),
#  ('Creative', 1),
#  ('Morfologic', 1),
#  ('(SGJP)', 1),
#  ('(http://sgjp.pl/morfeusz/)', 1),
#  ('Morphological', 1),
#  ('Analyzer', 1),
#  ('Integration', 1),
#  ('mecab-ipadic-2.7.0-20070801', 2),
#  ('http://jaist.dl.sourceforge.net/project/mecab/mecab-ipadic/2.7.0-20070801/mecab-ipadic-2.7.0-20070801.tar.gz',
#   1),
#  ('Nara', 1),
#  ('Science', 1),
#  ('(NAIST),', 1),
#  ('regard', 1),
#  ('implied', 1),
#  ('no', 2),
#  ('special,', 2),
#  ('indirect', 1),
#  ('consequential', 2),
#  ('whatsoever', 2),
#  ('resulting', 1),
#  ('loss', 1),
#  ('action', 1),
#  ('negligence', 1),
#  ('tortuous', 1),
#  ('out', 3),
#  ('connection', 2),
#  ('large', 1),
#  ('originate', 1),
#  ('Free', 2),
#  ('conditions', 1),
#  ('applies', 1),
#  ('current', 1),
#  ('Each', 3),
#  ('User', 2),
#  ('freely', 1),
#  ('Program,', 2),
#  ('third', 2),
#  ('parties,', 1),
#  ('PROVIDED', 1),
#  ('("NO', 1),
#  ('WARRANTY")', 1),
#  ('ALWAYS', 1),
#  ('appear', 1),
#  ('on,', 1),
#  ('substantially', 1),
#  ('set', 2),
#  ('neither', 2),
#  ('contravene', 1),
#  ('countries', 1),
#  ('itself.', 1),
#  ('NO', 1),
#  ('basis', 1),
#  ('research', 1),
#  ('during', 2),
#  ('basis.', 1),
#  ('whatsoever,', 1),
#  ('express,', 1),
#  ('otherwise.', 1),
#  ('term', 2),
#  ('performance,', 1),
#  ('particular', 1),
#  ('violation', 1),
#  ('right', 1),
#  ('party.', 1),
#  ('understand,', 1),
#  ('deemed', 2),
#  ('there', 1),
#  ('accordingly,', 1),
#  ('entire', 1),
#  ('risk', 1),
#  ('assumed', 1),
#  ('Therefore,', 1),
#  ('participated', 1),
#  ('respective', 1),
#  ('officers', 1),
#  ('damages,', 2),
#  ('incidental', 1),
#  ('material', 1),
#  ('result', 1),
#  ('program,', 2),
#  ('regardless', 1),
#  ('knowledge', 1),
#  ('possibility', 1),
#  ('foregoing', 1),
#  ('his', 1),
#  ('her', 1),
#  ('"use"', 1),
#  ('copying', 1),
#  ('production', 1),
#  ('where', 1),
#  ('person,', 2),
#  ('entity', 1),
#  ('than', 1),
#  ('grants', 1),
#  ('independently', 1),
#  ('exempted', 1),
#  ('above', 1),
#  ('far', 1),
#  ('concerned.', 1),
#  ('project,', 1),
#  ('Kryo.', 1),
#  ('2012', 1),
#  ('Dependencies:', 1),
#  ('2.17', 1),
#  ('3-Clause', 1),
#  ('http://code.google.com/p/kryo', 1),
#  ('1.7', 1),
#  ('V2.0', 1),
#  ('algorithms', 1),
#  ('Proximal.scala', 1),
#  ('details)', 1),
#  ('Debasish', 3),
#  ('Das', 3),
#  ('QuadraticMinimizer', 1),
#  ('breeze.optimize.proximal', 2),
#  ('NonlinearMinimizer', 1),
#  ('2015,', 1),
#  ('Solr', 1),
#  ('Mahout', 1),
#  ('Copyright', 85),
#  ('and', 81),
#  ('onwards', 1),
#  ('Software', 77),
#  ('Foundation.', 2),
#  ('This', 69),
#  ('product', 72),
#  ('includes', 31),
#  ('software', 41),
#  ('Foundation', 70),
#  ('(http://www.apache.org/).', 6),
#  ('Control', 2),
#  ('Notice', 2),
#  ('---------------------', 1),
#  ('cryptographic', 3),
#  ('which', 40),
#  ('you', 3),
#  ('currently', 3),
#  ('on', 35),
#  ('the', 158),
#  ('import,', 2),
#  ('re-export', 2),
#  ('to', 37),
#  ('another', 1),
#  ('encryption', 4),
#  ('BEFORE', 1),
#  ('any', 18),
#  ('please', 2),
#  ('your', 1),
#  ('regulations', 2),
#  ('concerning', 1),
#  ('or', 39),
#  ('see', 5),
#  ('if', 3),
#  ('permitted.', 1),
#  ('See', 9),
#  ('for', 34),
#  ('U.S.', 1),
#  ('Government', 1),
#  ('Department', 2),
#  ('Commerce,', 2),
#  ('Bureau', 1),
#  ('has', 19),
#  ('classified', 1),
#  ('(ECCN)', 1),
#  ('5D002.C.1,', 1),
#  ('information', 2),
#  ('performing', 1),
#  ('with', 19),
#  ('asymmetric', 1),
#  ('manner', 1),
#  ('makes', 2),
#  ('it', 2),
#  ('under', 27),
#  ('License', 37),
#  ('Exception', 1),
#  ('Technology', 3),
#  ('Unrestricted', 1),
#  ('(TSU)', 1),
#  ('(see', 2),
#  ('Regulations,', 1),
#  ('Section', 2),
#  ('740.13)', 1),
#  ('object', 1),
#  ('code', 12),
#  ('included', 6),
#  ('Commons', 23),
#  ('Crypto', 2),
#  ('data', 13),
#  ('across', 1),
#  ('between', 1),
#  ('services.', 1),
#  ('------------------------------------------------------------------', 2),
#  ('file', 13),
#  ('corresponding', 6),
#  ('section', 6),
#  ('License,', 6),
#  ('Version', 6),
#  ('2.0,', 6),
#  ('case', 6),
#  ('Beeline', 1),
#  ('Avro', 3),
#  ('2009-2014', 3),
#  ('contains', 20),
#  ('by', 66),
#  ('authors', 1),
#  ('identified', 1),
#  ('files;', 1),
#  ('such', 7),
#  ('missing', 1),
#  ('been', 8),
#  ('Tatu', 5),
#  ('For', 3),
#  ('(generally', 1),
#  ('people', 1),
#  ('who', 1),
#  ('problems)', 1),
#  ('Compress', 2),
#  ('2002-2012', 3),
#  ('Mapred', 1),
#  ('API', 5),
#  ('IPC', 1),
#  ('2006-2013', 1),
#  ('Joe', 1),
#  ('Walnes,', 1),
#  ('Henri', 1),
#  ('Tremblay,', 1),
#  ('Mesquita', 1),
#  ('::', 1),
#  ('5', 1),
#  ('shaded', 1),
#  ('(repackaged)', 1),
#  ('2005-2015', 1),
#  ('Consortium', 1),
#  ('bundles', 9),
#  ('binaries', 9),
#  ('notices:', 9),
#  ('<dain@iq80.com>', 1),
#  ('http://fusesource.com', 2),
#  ('org.fusesource.hawtjni:hawtjni-runtime', 1),
#  ('its', 3),
#  ('affiliates.', 1),
#  ('Gson', 1),
#  ('Netty', 5),
#  ('web', 1),
#  ('http://netty.io/', 1),
#  ('licenses', 1),
#  ('not', 6),
#  ('except', 1),
#  ('You', 1),
#  ('a', 46),
#  ('copy', 1),
#  ('http://www.apache.org/licenses/LICENSE-2.0', 2),
#  ('Unless', 1),
#  ('required', 1),
#  ('applicable', 1),
#  ('agreed', 3),
#  ('writing,', 2),
#  ('distributed', 10),
#  ('WITHOUT', 1),
#  ('WARRANTIES', 1),
#  ('OR', 1),
#  ('ANY', 1),
#  ('either', 2),
#  ('express', 1),
#  ('implied.', 1),
#  ('governing', 1),
#  ('permissions', 1),
#  ('Also,', 1),
#  ('each', 1),
#  ('file,', 3),
#  ('located', 1),
#  ('license', 2),
#  ('terms', 4),
#  ('that', 13),
#  ('on.', 1),
#  ('Framework', 2),
#  ('from', 34),
#  ('works', 1),
#  ('EG,', 1),
#  ('Doug', 1),
#  ('T.', 1),
#  ('http://gee.cs.oswego.edu/cgi-bin/viewcvs.cgi/jsr166/', 1),
#  ('Robert', 1),
#  ("Harder's", 1),
#  ('Base64', 1),
#  ('can', 32),
#  ('be', 43),
#  ('license/LICENSE.base64.txt', 1),
#  ('portion', 12),
#  ('WebSocket', 2),
#  ('license/LICENSE.webbit.txt', 1),
#  ('https://github.com/joewalnes/webbit', 1),
#  ('written', 9),
#  ('Bloch', 1),
#  ("'Apache", 6),
#  ("Harmony',", 1),
#  ('SE,', 1),
#  ('(Apache', 12),
#  ('2.0)', 11),
#  ('http://archive.apache.org/dist/harmony/', 1),
#  ('ASL2', 4),
#  ('AbstractNodeQueue,', 1),
#  ("Vyukov's", 1),
#  ('queue.', 1),
#  ('https://github.com/akka/akka/blob/wip-2.2.3-for-scala-2.11/akka-actor/src/main/java/akka/dispatch/AbstractNodeQueue.java',
#   1),
#  ("'jbzip2',", 1),
#  ('bzip2', 1),
#  ('compression', 6),
#  ('J.', 1),
#  ('Francis.', 1),
#  ('https://code.google.com/p/jbzip2/', 1),
#  ("'libdivsufsort',", 1),
#  ('suffix', 1),
#  ('Burrows-Wheeler', 1),
#  ('string', 2),
#  ('Mori.', 1),
#  ('license/LICENSE.libdivsufsort.txt', 1),
#  ('https://code.google.com/p/libdivsufsort/', 1),
#  ("Wakart's", 1),
#  ('Concurrency', 1),
#  ('Tools', 1),
#  ('(ASL2', 1),
#  ('https://github.com/JCTools/JCTools', 1),
#  ('optionally', 17),
#  ("'JZlib',", 2),
#  ('pure', 2),
#  ('http://www.jcraft.com/jzlib/', 2),
#  ("'Compress-LZF',", 1),
#  ('decoding', 1),
#  ('license/LICENSE.compress-lzf.txt', 1),
#  ("'lz4',", 1),
#  ('Grand.', 1),
#  ('license/LICENSE.lz4.txt', 1),
#  ('https://github.com/jpountz/lz4-java', 1),
#  ("'lzma-java',", 1),
#  ('license/LICENSE.lzma-java.txt', 1),
#  ('https://github.com/jponge/lzma-java', 1),
#  ("'jfastlz',", 1),
#  ('port', 1),
#  ('FastLZ', 1),
#  ('William', 1),
#  ('https://code.google.com/p/jfastlz/', 1),
#  ("'Protocol", 2),
#  ('BSD', 8),
#  ('temporary', 1),
#  ('X.509', 1),
#  ('certificate', 1),
#  ('does', 1),
#  ('equivalent', 1),
#  ('functionality.', 1),
#  ('http://www.bouncycastle.org/', 1),
#  ('Inc,', 1),
#  ('http://code.google.com/p/snappy/', 2),
#  ("Marshalling',", 1),
#  ('API,', 2),
#  ('LGPL', 3),
#  ('http://www.jboss.org/jbossmarshalling', 1),
#  ('framework,', 5),
#  ('http://code.google.com/p/caliper/', 1),
#  ('license/LICENSE.commons-logging.txt', 1),
#  ('http://commons.apache.org/logging/', 1),
#  ('http://logging.apache.org/log4j/', 1),
#  ("'Aalto", 1),
#  ("XML',", 1),
#  ('ultra-high', 1),
#  ('XML', 1),
#  ('processor,', 1),
#  ('http://wiki.fasterxml.com/AaltoHome', 1),
#  ...]
